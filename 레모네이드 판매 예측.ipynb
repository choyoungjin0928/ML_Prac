# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
#데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 독립변수, 종속변수
독립 = 데이터[['온도']]
종속 = 데이터[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
#모델을 만든다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
#모델을 학습한다.
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6329e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6319e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6313e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6306e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6297e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6286e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6283e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6280e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6278e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6281e-04

# %%
#모델을 이용한다.
model.predict(독립)
# Out:
# array([[39.99256 ],
#        [41.990894],
#        [43.98923 ],
#        [45.987564],
#        [47.9859  ],
#        [49.984234]], dtype=float32)

# %%
model.predict([15])
# Out:
# array([[30.000885]], dtype=float32)
